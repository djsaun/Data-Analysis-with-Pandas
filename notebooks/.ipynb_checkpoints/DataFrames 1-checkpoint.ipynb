# %%
import pandas as pd

# %%
nba = pd.read_csv("../files/nba.csv")

# %% [markdown]
# ## Shared Methods and Attributes

# %%
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape ## returns tuple of rows x columns
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns ## returns array of column names
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes ## combines index and columns
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info() ## provides summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts() ## returns a series with a count of each datatype
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# ## Differences Between Shared Methods

# %%
rev = pd.read_csv("../files/revenue.csv", index_col="Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
rev.sum() ## sums up each column
rev.sum(axis=1) ## sums up each row
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# ## Select One Column from a DataFrame

# %%
nba.Name ## returns series
nba.Number ## Doesn't work when column name has spaces
nba.Salary
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %%
nba["College"] ## returns series; can use column names witih spaces
nba["Salary"]
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %% [markdown]
# ## Select Two or More Columns From a DataFrame

# %%
nba[["Name", "Team"]]
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# ...

# %% [markdown]
# ## Add New Columns to a DataFrame

# %%
nba["Sport"] = "Basketball" ## scalar value -- every item will have "Basketball" in Sport column

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["League"] = "NBA"

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport League
# 0              Texas  7730337.0  Basketball    NBA
# 1          Marquette  6796117.0  Basketball    NBA
# 2  Boston University        NaN  Basketball    NBA

# %%
nba = pd.read_csv("../files/nba.csv")

# %%
nba.insert(3, column = "Sport", value = "Basketball")

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN

# %% [markdown]
# ## Broadcasting Operations

# %%
nba["Age"].add(5)
nba["Age"] + 5 ## adds 5
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
# 5      34.0
# 6      26.0
# 7      30.0
# 8      27.0
# 9      27.0
# 10     29.0
# 11     32.0
# 12     32.0
# 13     25.0
# 14     31.0
# 15     32.0
# 16     29.0
# 17     33.0
# 18     26.0
# 19     37.0
# 20     27.0
# 21     31.0
# 22     28.0
# 23     33.0
# 24     26.0
# 25     31.0
# 26     30.0
# 27     31.0
# 28     33.0
# 29     32.0
#        ...
# 428    30.0
# 429    28.0
# 430    29.0
# 431    32.0
# 432    28.0
# 433    33.0
# 434    39.0
# 435    29.0
# 436    30.0
# 437    29.0
# 438    28.0
# 439    31.0
# 440    35.0
# 441    25.0
# 442    33.0
# 443    28.0
# 444    29.0
# 445    25.0
# 446    29.0
# 447    28.0
# 448    31.0
# 449    28.0
# 450    33.0
# 451    31.0
# 452    25.0
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Salary"].sub(5000)
nba["Salary"] - 5000 ## subtracts 5000
# Out:
# 0       7725337.0
# 1       6791117.0
# 2             NaN
# 3       1143640.0
# 4       4995000.0
# 5      11995000.0
# 6       1165960.0
# 7       2160160.0
# 8       1819360.0
# 9       3426040.0
# 10      2564260.0
# 11      6907869.0
# 12      3420510.0
# 13      1744840.0
# 14      2611975.0
# 15      3420510.0
# 16       840059.0
# 17      1495000.0
# 18      1330480.0
# 19      6295000.0
# 20      1594840.0
# 21       129215.0
# 22      1495000.0
# 23     19684000.0
# 24      1135240.0
# 25       942276.0
# 26       976348.0
# 27       942276.0
# 28       942276.0
# 29     11230955.0
#           ...
# 428     8037895.0
# 429      620093.0
# 430      942276.0
# 431     6975802.0
# 432     2889059.0
# 433     5995000.0
# 434     5011000.0
# 435     3070880.0
# 436     4231287.0
# 437     2520160.0
# 438      520093.0
# 439     1410520.0
# 440     2849940.0
# 441     2632720.0
# 442     4770000.0
# 443     2653240.0
# 444     9458484.0
# 445     3772720.0
# 446    11995000.0
# ...

# %%
nba["Weight"].mul(2)
nba["Weight"] * 2 ## multiplies by 2
# Out:
# 0      360.0
# 1      470.0
# 2      410.0
# 3      370.0
# 4      462.0
# 5      480.0
# 6      470.0
# 7      476.0
# 8      380.0
# 9      440.0
# 10     520.0
# 11     370.0
# 12     440.0
# 13     430.0
# 14     506.0
# 15     432.0
# 16     380.0
# 17     400.0
# 18     440.0
# 19     400.0
# 20     416.0
# 21     438.0
# 22     350.0
# 23     550.0
# 24     400.0
# 25     440.0
# 26     474.0
# 27     496.0
# 28     410.0
# 29     442.0
#        ...
# 428    430.0
# 429    412.0
# 430    420.0
# 431    480.0
# 432    430.0
# 433    430.0
# 434    530.0
# 435    490.0
# 436    390.0
# 437    400.0
# 438    370.0
# 439    470.0
# 440    346.0
# 441    480.0
# 442    456.0
# 443    382.0
# 444    428.0
# 445    380.0
# 446    530.0
# 447    490.0
# 448    452.0
# 449    412.0
# 450    452.0
# 451    412.0
# 452    468.0
# 453    406.0
# 454    358.0
# 455    512.0
# 456    462.0
# 457      NaN
# Name: Weight, Length: 458, dtype: float64

# %%
## save new series as new column within DataFrame 
nba["Weight in Kilograms"] = nba["Weight"] * 0.453592
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kilograms
# 0              Texas  7730337.0             81.64656
# 1          Marquette  6796117.0            106.59412
# 2  Boston University        NaN             92.98636

# %%
nba["Salary"].div(1000000)
nba["Salary in Millions"] = nba["Salary"] / 1000000 ## divides by 1,000,000
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0             81.64656            7.730337
# 1          Marquette  6796117.0            106.59412            6.796117
# 2  Boston University        NaN             92.98636                 NaN

# %% [markdown]
# ## Drop Rows with Null Values

# %%
nba.dropna() ## removes any rows from the DataFrame that have any null values
nba.dropna(how = "all", inplace = True) ## removes any rows from the DataFrame where all data are null

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary  Weight in Kilograms  Salary in Millions
# 452  2239800.0           106.140528            2.239800
# 453  2433333.0            92.079176            2.433333
# 454   900000.0            81.192968            0.900000
# 455  2900000.0           116.119552            2.900000
# 456   947276.0           104.779752            0.947276

# %%
nba.dropna(axis = 1) ## removes any columns from the DataFrame that have any null values
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.dropna(subset = ["Salary"]) ## Can add list of strings to “subset” param in order to specify which columns should be checked for null values and removed if any are present
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# ...
